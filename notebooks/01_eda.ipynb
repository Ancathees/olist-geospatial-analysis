# %% [markdown]
# # Notebook 01 — Exploratory Data Analysis
# Downloads the Olist dataset and profiles all 8 tables.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from src.data_loader import download_dataset, load_tables, cache_tables
import src.data_loader
import importlib
import sys
sys.path.insert(0, '..')

importlib.reload(src.data_loader)


print('Imports OK')
# Out:
# Imports OK

# %%
# Downloads only if not cached
tables = load_tables()
print(list(tables.keys()))
# Out:
# Loaded 8 tables.
# ['olist_orders_dataset', 'olist_order_items_dataset', 'olist_order_payments_dataset', 'olist_order_reviews_dataset', 'olist_customers_dataset', 'olist_sellers_dataset', 'olist_products_dataset', 'olist_geolocation_dataset']

# %%
# Persist raw tables to outputs/processed_data/ as CSV
cache_tables(tables)
# Out:
# Cached 8 tables to C:\Users\Angie\OneDrive\Documentos\Analista de Datos\PORTAFOLIO\PROYECTO_3\outputs\processed_data

# %% [markdown]
# ## Table Profiles

# %%
for name, df in tables.items():
    print(f"\n{'='*60}")
    print(f"  {name}  — shape: {df.shape}")
    print(f"{'='*60}")
    display(df.dtypes.to_frame('dtype'))
    display(df.head(3))
# Out:
# ...
#   olist_orders_dataset  — shape: (99441, 8)
# ...
#                                 dtype
# order_id                       object
# customer_id                    object
# order_status                   object
# order_purchase_timestamp       object
# order_approved_at              object
# order_delivered_carrier_date   object
# order_delivered_customer_date  object
# order_estimated_delivery_date  object
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
#
# ...

# %% [markdown]
# ## Null Summary

# %%
for name, df in tables.items():
    null_counts = df.isnull().sum()
    if null_counts.sum() > 0:
        print(f'\n{name}')
        display(null_counts[null_counts > 0].to_frame('nulls'))
# Out:
# olist_orders_dataset
#                                nulls
# order_approved_at                160
# order_delivered_carrier_date    1783
# order_delivered_customer_date   2965
# olist_order_reviews_dataset
#                         nulls
# review_comment_title    87656
# review_comment_message  58247
# olist_products_dataset
#                             nulls
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2

# %% [markdown]
# ## Orders Timeline

# %%
orders = tables['olist_orders_dataset'].copy()
orders['order_purchase_timestamp'] = pd.to_datetime(
    orders['order_purchase_timestamp'])
orders['month'] = orders['order_purchase_timestamp'].dt.to_period('M')

monthly = orders.groupby('month').size().reset_index(name='count')
monthly['month_str'] = monthly['month'].astype(str)

fig, ax = plt.subplots(figsize=(14, 4))
ax.bar(monthly['month_str'], monthly['count'], color='steelblue')
ax.set_xlabel('Month')
ax.set_ylabel('Orders')
ax.set_title('Monthly Order Volume')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Geolocation Overview

# %%
geo = tables['olist_geolocation_dataset']
print(f'Geolocation rows: {len(geo):,}')
print(f'Unique ZIPs:       {geo["geolocation_zip_code_prefix"].nunique():,}')
print(
    f'Lat range:  {geo["geolocation_lat"].min():.2f} to {geo["geolocation_lat"].max():.2f}')
print(
    f'Lng range:  {geo["geolocation_lng"].min():.2f} to {geo["geolocation_lng"].max():.2f}')
# Out:
# Geolocation rows: 1,000,163
# Unique ZIPs:       19,015
# Lat range:  -36.61 to 45.07
# Lng range:  -101.47 to 121.11
